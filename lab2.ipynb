# %% [markdown]
# # Lab 2

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia-340-2-fall25147258/Crime_Data_from_2020_to_Present.csv') # load the data from s3
df.head() #show the top 5 rows; df.tail() will give last 5 rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
df.shape #show the number of rows and columns
# Out:
# (1004991, 28)

# %%
df.sort_values(by='AREA NAME') #sort data by a column
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 705893  231224527  12/08/2023 12:00:00 AM  11/29/2023 12:00:00 AM      1100
# 896876  241205730  01/29/2024 12:00:00 AM  01/29/2024 12:00:00 AM       200
# 680921  231205158  01/21/2023 12:00:00 AM  01/21/2023 12:00:00 AM      1214
# 220864  211225451  12/21/2021 12:00:00 AM  12/21/2021 12:00:00 AM       300
# 680904  231216729  07/31/2023 12:00:00 AM  07/29/2023 12:00:00 AM      1300
# ...           ...                     ...                     ...       ...
# 245352  210714125  10/08/2021 12:00:00 AM  10/08/2021 12:00:00 AM      1100
# 760230  230704280  01/07/2023 12:00:00 AM  01/07/2023 12:00:00 AM      1935
# 99545   200710772  06/21/2020 12:00:00 AM  06/21/2020 12:00:00 AM       618
# 846781  230712604  07/28/2023 12:00:00 AM  07/28/2023 12:00:00 AM      1845
# 525018  220706443  03/07/2022 12:00:00 AM  03/02/2022 12:00:00 AM      2200
#
# ...

# %%
df[df['AREA']>10] # select rows by values
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830
# 7        201115217  10/29/2020 12:00:00 AM  07/07/2020 12:00:00 AM      1400
# 8        241708596  04/20/2024 12:00:00 AM  03/02/2020 12:00:00 AM      1200
# ...            ...                     ...                     ...       ...
# 1004985  251904120  02/12/2025 12:00:00 AM  02/12/2025 12:00:00 AM      1430
# 1004986  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130
# 1004988  251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM      1554
# 1004989  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1600
# 1004990  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235
#
# ...

# %%
df.info() # shows the data types and number of null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
# ...

# %%
df.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06
# mean   2.202215e+08  1.339900e+03  1.069174e+01  1.115633e+03  1.400348e+00
# std    1.319718e+07  6.510613e+02  6.110255e+00  6.111605e+02  4.899691e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209159e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311103e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.004991e+06  1.004991e+06  1.004975e+06   327247.000000  1.004980e+06
# mean   5.001568e+02  2.891706e+01  3.056201e+02      363.955300  4.999174e+02
# ...

# %% [markdown]
# This data contains 1,004,991 rows and 28 columns; there is a combination of text and numeric values - the values consist of locations and crime descriptions; this is a very large data set with over 1 million instances - a few of the columns seem unnecessary from a quick glance.

# %%
df = df.rename(columns={"AREA NAME":"REGION"})

# %%
df.isnull().sum() #show the number of rows containing null value
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# REGION                  0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151619
# Vict Age                0
# Vict Sex           144644
# Vict Descent       144656
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677744
# Weapon Desc        677744
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935831
# Crm Cd 3          1002677
# Crm Cd 4          1004927
# LOCATION                0
# Cross Street       850755
# LAT                     0
# LON                     0
# dtype: int64

# %%
df = df.drop(columns={"Crm Cd 2","Crm Cd 3","Crm Cd 4","Cross Street"})

# %% [markdown]
# I renamed "AREA LOC" to "REGION" to further isolate the "AREA" column; the columns "Crm Cd 2", "Crm Cd 3", "Crm Cd 4", and "Cross Street" contained more than 50% missing values so I dropped each of these columns to reduce null values. Null values still exist in the data.

# %%
df['Crm Cd Desc']
# Out:
# 0                                          THEFT OF IDENTITY
# 1             ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2                                          THEFT OF IDENTITY
# 3          THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4            THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
#                                  ...
# 1004986                            OTHER MISCELLANEOUS CRIME
# 1004987                       CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988                                    INDECENT EXPOSURE
# 1004989                             BATTERY - SIMPLE ASSAULT
# 1004990                                    INDECENT EXPOSURE
# Name: Crm Cd Desc, Length: 1004991, dtype: object

# %%
df.sort_values(by='AREA')
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 353123   210112857  07/02/2021 12:00:00 AM  07/02/2021 12:00:00 AM       905
# 752514   240110476  04/18/2024 12:00:00 AM  11/15/2023 12:00:00 AM      1200
# 752521   230114988  06/28/2023 12:00:00 AM  06/28/2023 12:00:00 AM      1000
# 353055   230114546  06/20/2023 12:00:00 AM  10/22/2021 12:00:00 AM      1955
# 1004758  240116145  08/05/2024 12:00:00 AM  08/05/2024 12:00:00 AM       820
# ...            ...                     ...                     ...       ...
# 1004925  252104132  03/08/2025 12:00:00 AM  02/23/2025 12:00:00 AM      1900
# 12       202113531  09/06/2020 12:00:00 AM  09/05/2020 12:00:00 AM      1500
# 588575   222104905  01/27/2022 12:00:00 AM  01/21/2022 12:00:00 AM      2000
# 1004986  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130
# 588616   222113783  09/02/2022 12:00:00 AM  09/01/2022 12:00:00 AM        20
#
# ...

# %%
df[100:111]
# Out:
#          DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 100  201317392  09/22/2020 12:00:00 AM  09/22/2020 12:00:00 AM      2100
# 101  201509791  05/09/2020 12:00:00 AM  05/09/2020 12:00:00 AM      1530
# 102  202011800  07/06/2020 12:00:00 AM  07/04/2020 12:00:00 AM      1800
# 103  202114356  09/30/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1730
# 104  201518230  12/02/2020 12:00:00 AM  11/17/2020 12:00:00 AM       900
# 105  202018006  12/04/2020 12:00:00 AM  12/03/2020 12:00:00 AM      1800
# 106  201313980  07/15/2020 12:00:00 AM  07/15/2020 12:00:00 AM       150
# 107  230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900
# 108  201315254  08/09/2020 12:00:00 AM  08/09/2020 12:00:00 AM      1830
# 109  201812631  06/16/2020 12:00:00 AM  06/16/2020 12:00:00 AM       331
# 110  201420929  11/29/2020 12:00:00 AM  11/28/2020 12:00:00 AM      2100
#
#      AREA       REGION  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
df = df[(df['TIME OCC']>=2100) & (df['Part 1-2']>=2)]
df[20:31]
# Out:
#          DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 360  201509531  05/03/2020 12:00:00 AM  05/03/2020 12:00:00 AM      2340
# 439  201421964  12/21/2020 12:00:00 AM  12/21/2020 12:00:00 AM      2200
# 448  201915778  10/17/2020 12:00:00 AM  10/16/2020 12:00:00 AM      2300
# 484  201814674  07/28/2020 12:00:00 AM  07/27/2020 12:00:00 AM      2125
# 496  202013190  08/07/2020 12:00:00 AM  08/07/2020 12:00:00 AM      2145
# 551  202005753  02/06/2020 12:00:00 AM  02/06/2020 12:00:00 AM      2130
# 556  202108275  04/14/2020 12:00:00 AM  04/14/2020 12:00:00 AM      2330
# 564  201420530  11/18/2020 12:00:00 AM  09/30/2020 12:00:00 AM      2136
# 567  201606565  03/03/2020 12:00:00 AM  03/02/2020 12:00:00 AM      2130
# 569  201818724  10/12/2020 12:00:00 AM  10/12/2020 12:00:00 AM      2215
# 575  202116532  12/01/2020 12:00:00 AM  12/01/2020 12:00:00 AM      2115
#
#      AREA       REGION  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
df['REGION'].value_counts()
# Out:
# REGION
# Central        3397
# 77th Street    3388
# Southwest      2990
# Hollywood      2869
# Southeast      2779
# Olympic        2726
# N Hollywood    2585
# Pacific        2544
# Rampart        2454
# Mission        2440
# Harbor         2392
# Newton         2319
# West Valley    2271
# Northeast      2132
# Wilshire       2125
# Van Nuys       2097
# Hollenbeck     2044
# Topanga        2026
# Devonshire     1996
# Foothill       1888
# West LA        1847
# Name: count, dtype: int64

# %%
df['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# BATTERY - SIMPLE ASSAULT                                   10303
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    10147
# INTIMATE PARTNER - SIMPLE ASSAULT                           9230
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)                    3826
# THEFT OF IDENTITY                                           2552
#                                                            ...
# LYNCHING - ATTEMPTED                                           1
# DOCUMENT WORTHLESS ($200 & UNDER)                              1
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)             1
# PETTY THEFT - AUTO REPAIR                                      1
# GRAND THEFT / INSURANCE FRAUD                                  1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# I displayed the Crime Code Description column which displayed the written explaination of what the crime was; then sorted rows by AREA which unified each of the different sections; I sliced rows 100 to 110 to see a different section of data than I already have; then filtered the data by crimes after 2100 (9pm) and Part 2 crimes which are 'lesser' offenses. I also did value counts for the Decriptions and Regions for possible later use.

# %% [markdown]
# ## Visualizations

# %%
df = df[['Date Rptd','DATE OCC','TIME OCC','AREA','REGION','Crm Cd Desc']]
df.head()
# Out:
#                  Date Rptd                DATE OCC  TIME OCC  AREA     REGION  \
# 29  08/09/2020 12:00:00 AM  08/09/2020 12:00:00 AM      2250    20    Olympic
# 50  04/12/2020 12:00:00 AM  04/12/2020 12:00:00 AM      2221    19    Mission
# 71  01/05/2020 12:00:00 AM  01/04/2020 12:00:00 AM      2219    14    Pacific
# 74  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300    18  Southeast
# 80  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2100    19    Mission
#
#                                 Crm Cd Desc
# 29        INTIMATE PARTNER - SIMPLE ASSAULT
# 50  CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# 71  LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# 74                        THEFT OF IDENTITY
# 80                 BATTERY - SIMPLE ASSAULT

# %%
df.hist(layout=(3,3), figsize=(10, 5), sharey=False, sharex=False, bins=50) #use multiple charts to show the distribution of all columns
# Out:
# array([[<Axes: title={'center': 'TIME OCC'}>,
#         <Axes: title={'center': 'AREA'}>, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# The first graph shows the most common time crimes are reported showing significant peaks at the whole hour values (2100,2200,2300) and the 30 minute marks (2130,2230,2330). This is useful as it shows many reports may round or approximate the time of the crime rather than utilize the exact time. The second graph demostrates the areas which experience the most reports. Primarily Area 1 and Area 12.

# %%
sum_time_by_area = df.groupby('TIME OCC').count()
sum_time_by_area.plot()
# Out:
# <Axes: xlabel='TIME OCC'>

# %% [markdown]
# The first set of charts displays histographs of the Time Occured and the Area as reported. The Line chart displays a more detailed breakdown of the time occured data.
